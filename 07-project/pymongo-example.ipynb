# %% [markdown]
# Load some data from the pymongo database

# %%
import pymongo

# %%
client = pymongo.MongoClient('mongodb://localhost:27018')
db = client.get_database("prediction_service")

# %%
# load data collections
data_collection = db.get_collection("data")

# %%
data = list(data_collection.find())

# %%
data
# Out:
# [{'_id': ObjectId('62ff9ae7a4c054ef37b7098e'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0',
#   'prediction': 15.69429874420166},
#  {'_id': ObjectId('62ff9b69160a1d8639f4f0ee'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0',
#   'prediction': 15.69429874420166},
#  {'_id': ObjectId('62ff9ba2428fac5b6005ac02'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0',
#   'prediction': 15.69429874420166},
#  {'_id': ObjectId('62ff9dc589049db239a45eef'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0',
#   'prediction': 15.69429874420166},
#  {'_id': ObjectId('62ff9e4253f81e15df7fd4f1'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0',
#   'prediction': 15.69429874420166},
#  {'_id': ObjectId('62ff9eb7f29c93f59b491db1'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0',
#   'prediction': 15.69429874420166},
#  {'_id': ObjectId('62ff9f290f206f68f087646b'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0',
#   'prediction': 15.69429874420166},
#  {'_id': ObjectId('62ff9f6a4fa515b53b6b692c'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0',
#   'prediction': 15.69429874420166},
#  {'_id': ObjectId('62ff9f754fa515b53b6b692d'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 15.55,
#   'cooling_load': 21.33,
#   'id': '1f3c9d21-a207-4e43-800f-5c1510bf6937',
#   'prediction': 15.652251243591309},
#  {'_id': ObjectId('62ff9f764fa515b53b6b692e'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 15.55,
#   'cooling_load': 21.33,
#   'id': '858c896f-8460-4f22-947d-136cfc1c9e6e',
#   'prediction': 15.652251243591309},
#  {'_id': ObjectId('62ff9f774fa515b53b6b692f'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 15.55,
#   'cooling_load': 21.33,
#   'id': 'a0430d7b-f61b-4599-8312-2e61093793d8',
#   'prediction': 15.652251243591309},
#  {'_id': ObjectId('62ff9f784fa515b53b6b6930'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 15.55,
#   'cooling_load': 21.33,
#   'id': '240d7c60-456c-4bf6-8537-387dd85d9d0c',
#   'prediction': 15.652251243591309},
#  {'_id': ObjectId('62ff9f794fa515b53b6b6931'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 20.84,
#   'cooling_load': 28.28,
#   'id': 'a9deadfb-5d49-4608-a770-05d548068816',
#   'prediction': 21.158700942993164},
#  {'_id': ObjectId('62ff9f7a4fa515b53b6b6932'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 21.46,
#   'cooling_load': 25.38,
#   'id': '74e8dcfc-6359-4d23-9e72-9598712111b5',
#   'prediction': 21.158700942993164},
#  {'_id': ObjectId('62ff9f7b4fa515b53b6b6933'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 20.71,
#   'cooling_load': 25.16,
#   'id': '493d83e4-54ba-4160-a68c-475889cf9641',
#   'prediction': 21.158700942993164},
#  {'_id': ObjectId('62ff9f7c4fa515b53b6b6934'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 19.68,
#   'cooling_load': 29.6,
#   'id': 'b11b19a8-89f1-4bb5-b748-8a4cff85a61a',
#   'prediction': 21.158700942993164},
#  {'_id': ObjectId('62ff9f7d4fa515b53b6b6935'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 19.5,
#   'cooling_load': 27.3,
#   'id': 'a0c3f320-40c9-4262-8c97-7361aba5834a',
#   'prediction': 18.813987731933594},
#  {'_id': ObjectId('62ff9f7e4fa515b53b6b6936'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 19.95,
#   'cooling_load': 21.97,
#   'id': 'b9f114ef-4538-4c48-ac90-ef1592ffdb72',
#   'prediction': 18.813987731933594},
#  {'_id': ObjectId('62ff9f7f4fa515b53b6b6937'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 19.34,
#   'cooling_load': 23.49,
#   'id': 'ac39dc78-d25b-4e93-8456-ede3de02f289',
#   'prediction': 18.813987731933594},
#  {'_id': ObjectId('62ff9f804fa515b53b6b6938'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 18.31,
#   'cooling_load': 27.87,
#   'id': 'b8ea08ef-5446-4ba0-94a1-42ab6dd4c26e',
#   'prediction': 18.813987731933594},
#  {'_id': ObjectId('62ff9f814fa515b53b6b6939'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 17.05,
#   'cooling_load': 23.77,
#   'id': '9e164085-6388-4f05-9d91-8d450217dcde',
#   'prediction': 16.802690505981445},
#  {'_id': ObjectId('62ff9f824fa515b53b6b693a'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 17.41,
#   'cooling_load': 21.46,
#   'id': '9e4d2106-fa60-4324-95ca-592b8f39b606',
#   'prediction': 16.802690505981445},
#  {'_id': ObjectId('62ff9f834fa515b53b6b693b'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 16.95,
#   'cooling_load': 21.16,
#   'id': '32444c96-e305-43b4-ad17-8e24fdb0cb20',
#   'prediction': 16.802690505981445},
#  {'_id': ObjectId('62ff9f844fa515b53b6b693c'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 15.98,
#   'cooling_load': 24.93,
#   'id': '627684ac-067c-476d-8fa0-c4d8bae15645',
#   'prediction': 16.802690505981445},
#  {'_id': ObjectId('62ff9f854fa515b53b6b693d'),
#   'relative_compactnes': 0.79,
#   'surface_area': 637.0,
#   'wall_area': 343.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 28.52,
#   'cooling_load': 37.73,
#   'id': '0513c48b-5800-48cf-bc09-a7babd6731aa',
#   'prediction': 29.251333236694336},
#  {'_id': ObjectId('62ff9f864fa515b53b6b693e'),
#   'relative_compactnes': 0.79,
#   'surface_area': 637.0,
#   'wall_area': 343.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 29.9,
#   'cooling_load': 31.27,
#   'id': '94f379ad-1370-459b-a461-9b1597a7c37d',
#   'prediction': 29.251333236694336},
#  {'_id': ObjectId('62ff9f874fa515b53b6b693f'),
#   'relative_compactnes': 0.79,
#   'surface_area': 637.0,
#   'wall_area': 343.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 29.63,
#   'cooling_load': 30.93,
#   'id': '81c288b3-2a04-4a54-8766-ff091049eaf6',
#   'prediction': 29.251333236694336},
#  {'_id': ObjectId('62ff9f884fa515b53b6b6940'),
#   'relative_compactnes': 0.79,
#   'surface_area': 637.0,
#   'wall_area': 343.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 28.75,
#   'cooling_load': 39.44,
#   'id': '39806219-acaf-4d42-8d92-61728840fd60',
#   'prediction': 29.251333236694336},
#  {'_id': ObjectId('62ff9f894fa515b53b6b6941'),
#   'relative_compactnes': 0.76,
#   'surface_area': 661.5,
#   'wall_area': 416.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 24.77,
#   'cooling_load': 29.79,
#   'id': '5ae5b11c-8b6a-435f-bd7e-46e44bffacd1',
#   'prediction': 24.745895385742188},
#  {'_id': ObjectId('62ff9f8a4fa515b53b6b6942'),
#   'relative_compactnes': 0.76,
#   'surface_area': 661.5,
#   'wall_area': 416.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 23.93,
#   'cooling_load': 29.68,
#   'id': '9afa48a6-341d-4be1-a0c2-9c1d6f11cf1c',
#   'prediction': 24.745895385742188},
#  {'_id': ObjectId('62ff9f8b4fa515b53b6b6943'),
#   'relative_compactnes': 0.76,
#   'surface_area': 661.5,
#   'wall_area': 416.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 24.77,
#   'cooling_load': 29.79,
#   'id': '0fed8a07-5497-4392-b5ec-2e8f96944c3d',
#   'prediction': 24.745895385742188},
#  {'_id': ObjectId('62ff9f8c4fa515b53b6b6944'),
#   'relative_compactnes': 0.76,
#   'surface_area': 661.5,
#   'wall_area': 416.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 23.93,
#   'cooling_load': 29.4,
#   'id': '669b7860-95ef-4d5d-bfdf-6db7269b5897',
#   'prediction': 24.745895385742188},
#  {'_id': ObjectId('62ff9f8d4fa515b53b6b6945'),
#   'relative_compactnes': 0.74,
#   'surface_area': 686.0,
#   'wall_area': 245.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 6.07,
#   'cooling_load': 10.9,
#   'id': '5511a75f-59ce-444c-8e7e-3eab0bfcbc40',
#   'prediction': 6.08109188079834},
#  {'_id': ObjectId('62ff9f8e4fa515b53b6b6946'),
#   'relative_compactnes': 0.74,
#   'surface_area': 686.0,
#   'wall_area': 245.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 6.05,
#   'cooling_load': 11.19,
#   'id': '0640a1da-106e-4b3f-92ca-fc7b8ddabada',
#   'prediction': 6.08109188079834},
#  {'_id': ObjectId('62ff9f8f4fa515b53b6b6947'),
#   'relative_compactnes': 0.74,
#   'surface_area': 686.0,
#   'wall_area': 245.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 6.01,
#   'cooling_load': 10.94,
#   'id': '19b5baef-aaff-4d20-839e-5c9e91aff906',
#   'prediction': 6.08109188079834},
#  {'_id': ObjectId('62ff9f914fa515b53b6b6948'),
#   'relative_compactnes': 0.74,
#   'surface_area': 686.0,
#   'wall_area': 245.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 6.04,
#   'cooling_load': 11.17,
#   'id': '2c3a8a23-985c-40a0-a563-c1838ac276ac',
#   'prediction': 6.08109188079834},
#  {'_id': ObjectId('62ff9f924fa515b53b6b6949'),
#   'relative_compactnes': 0.71,
#   'surface_area': 710.5,
#   'wall_area': 269.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 6.37,
#   'cooling_load': 11.27,
#   'id': 'c29f5940-4a9b-4dba-969a-2cda1cbb41b3',
#   'prediction': 6.347239017486572},
#  {'_id': ObjectId('62ff9f934fa515b53b6b694a'),
#   'relative_compactnes': 0.71,
#   'surface_area': 710.5,
#   'wall_area': 269.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 6.4,
#   'cooling_load': 11.72,
#   'id': 'd078e7fb-d155-42d6-ac2e-33511d46fef7',
#   'prediction': 6.347239017486572},
#  {'_id': ObjectId('62ff9f944fa515b53b6b694b'),
#   'relative_compactnes': 0.71,
#   'surface_area': 710.5,
#   'wall_area': 269.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 6.37,
#   'cooling_load': 11.29,
#   'id': 'cdb26934-acfb-4685-91bf-691b167dc947',
#   'prediction': 6.347239017486572},
#  {'_id': ObjectId('62ff9f954fa515b53b6b694c'),
#   'relative_compactnes': 0.71,
#   'surface_area': 710.5,
#   'wall_area': 269.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 6.4,
#   'cooling_load': 11.67,
#   'id': 'dc3af825-a6d2-4a73-877d-452480ca3e86',
#   'prediction': 6.347239017486572},
#  {'_id': ObjectId('62ff9f964fa515b53b6b694d'),
#   'relative_compactnes': 0.69,
#   'surface_area': 735.0,
#   'wall_area': 294.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 6.85,
#   'cooling_load': 11.74,
#   'id': '7feee949-a4de-4b3d-88d5-a7d0ac4d3de6',
#   'prediction': 7.010278224945068},
#  {'_id': ObjectId('62ff9f974fa515b53b6b694e'),
#   'relative_compactnes': 0.69,
#   'surface_area': 735.0,
#   'wall_area': 294.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 6.79,
#   'cooling_load': 12.05,
#   'id': '00dfca9a-d4f3-4050-990b-d6c73dc91667',
#   'prediction': 7.010278224945068},
#  {'_id': ObjectId('62ff9f984fa515b53b6b694f'),
#   'relative_compactnes': 0.69,
#   'surface_area': 735.0,
#   'wall_area': 294.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 6.77,
#   'cooling_load': 11.73,
#   'id': '3267518d-d168-4c73-8ea6-047ee247b30b',
#   'prediction': 7.010278224945068},
#  {'_id': ObjectId('62ff9f994fa515b53b6b6950'),
#   'relative_compactnes': 0.69,
#   'surface_area': 735.0,
#   'wall_area': 294.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 6.81,
#   'cooling_load': 11.93,
#   'id': '72ba4f89-6b90-41a9-b459-ce997302f8d8',
#   'prediction': 7.010278224945068},
#  {'_id': ObjectId('62ff9f9a4fa515b53b6b6951'),
#   'relative_compactnes': 0.66,
#   'surface_area': 759.5,
#   'wall_area': 318.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 7.18,
#   'cooling_load': 12.4,
#   'id': '4fb35dda-3272-4ca5-8d94-5114e517d1de',
#   'prediction': 7.0856709480285645},
#  {'_id': ObjectId('62ff9f9b4fa515b53b6b6952'),
#   'relative_compactnes': 0.66,
#   'surface_area': 759.5,
#   'wall_area': 318.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 7.1,
#   'cooling_load': 12.23,
#   'id': 'ba033c2e-2d09-426f-af6c-ed9ea35f55ee',
#   'prediction': 7.0856709480285645},
#  {'_id': ObjectId('62ff9f9c4fa515b53b6b6953'),
#   'relative_compactnes': 0.66,
#   'surface_area': 759.5,
#   'wall_area': 318.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 7.1,
#   'cooling_load': 12.4,
#   'id': '5c6dd57c-ea90-4fff-a065-affe15b92342',
#   'prediction': 7.0856709480285645},
#  {'_id': ObjectId('62ff9f9d4fa515b53b6b6954'),
#   'relative_compactnes': 0.66,
#   'surface_area': 759.5,
#   'wall_area': 318.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 7.1,
#   'cooling_load': 12.14,
#   'id': '3db54515-1f47-462c-8676-5ffde2e92244',
#   'prediction': 7.0856709480285645},
#  {'_id': ObjectId('62ff9f9e4fa515b53b6b6955'),
#   'relative_compactnes': 0.64,
#   'surface_area': 784.0,
#   'wall_area': 343.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 10.85,
#   'cooling_load': 16.78,
#   'id': 'f711b9ad-0e39-4ecd-b086-419ebb653f8f',
#   'prediction': 10.699471473693848},
#  {'_id': ObjectId('62ff9f9f4fa515b53b6b6956'),
#   'relative_compactnes': 0.64,
#   'surface_area': 784.0,
#   'wall_area': 343.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 10.54,
#   'cooling_load': 16.8,
#   'id': '7589126f-3fd0-479c-9587-af702a2c019c',
#   'prediction': 10.699471473693848},
#  {'_id': ObjectId('62ff9fa04fa515b53b6b6957'),
#   'relative_compactnes': 0.64,
#   'surface_area': 784.0,
#   'wall_area': 343.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 10.77,
#   'cooling_load': 16.75,
#   'id': '24036f2e-16c3-47f0-9674-de946ed71f38',
#   'prediction': 10.699471473693848},
#  {'_id': ObjectId('62ff9fa14fa515b53b6b6958'),
#   'relative_compactnes': 0.64,
#   'surface_area': 784.0,
#   'wall_area': 343.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 10.56,
#   'cooling_load': 16.67,
#   'id': '893975cb-2a8c-4e5d-a4c7-d073a1e1ab61',
#   'prediction': 10.699471473693848},
#  {'_id': ObjectId('62ff9fa24fa515b53b6b6959'),
#   'relative_compactnes': 0.62,
#   'surface_area': 808.5,
#   'wall_area': 367.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 8.6,
#   'cooling_load': 12.07,
#   'id': '613a3e6c-a357-4235-b8f4-6742361674b5',
#   'prediction': 8.58272933959961},
#  {'_id': ObjectId('62ff9fa34fa515b53b6b695a'),
#   'relative_compactnes': 0.62,
#   'surface_area': 808.5,
#   'wall_area': 367.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 8.49,
#   'cooling_load': 12.22,
#   'id': 'c35260f0-4306-42a6-aa01-872b247d7f21',
#   'prediction': 8.58272933959961},
#  {'_id': ObjectId('62ff9fa44fa515b53b6b695b'),
#   'relative_compactnes': 0.62,
#   'surface_area': 808.5,
#   'wall_area': 367.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 8.45,
#   'cooling_load': 12.08,
#   'id': '4cf47025-cd0b-467f-87fe-d7b2d5199d00',
#   'prediction': 8.58272933959961},
#  {'_id': ObjectId('62ff9fa54fa515b53b6b695c'),
#   'relative_compactnes': 0.62,
#   'surface_area': 808.5,
#   'wall_area': 367.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 8.5,
#   'cooling_load': 12.04,
#   'id': 'e024f508-1a3c-46d2-8c77-a0bf545fb41b',
#   'prediction': 8.58272933959961},
#  {'_id': ObjectId('62ff9fa64fa515b53b6b695d'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 24.58,
#   'cooling_load': 26.47,
#   'id': '7902b3fb-6194-4bbe-bd1c-82a11aea5f0e',
#   'prediction': 24.408824920654297},
#  {'_id': ObjectId('62ff9fa74fa515b53b6b695e'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 24.63,
#   'cooling_load': 26.37,
#   'id': '7f513981-aaa4-4802-920f-2b63cd69404c',
#   'prediction': 24.408824920654297},
#  {'_id': ObjectId('62ff9fa94fa515b53b6b695f'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 24.63,
#   'cooling_load': 26.44,
#   'id': '57d3c36e-1dac-4a1d-a39d-5acfe61c01f2',
#   'prediction': 24.408824920654297},
#  {'_id': ObjectId('62ff9faa4fa515b53b6b6960'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 24.59,
#   'cooling_load': 26.29,
#   'id': '1a9abfb5-dc71-4ae7-9ac2-16f205fffb54',
#   'prediction': 24.408824920654297},
#  {'_id': ObjectId('62ff9fab4fa515b53b6b6961'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 29.03,
#   'cooling_load': 32.92,
#   'id': '3f5892a6-d1e6-4a21-a0a5-386c669af772',
#   'prediction': 28.606842041015625},
#  {'_id': ObjectId('62ff9fac4fa515b53b6b6962'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 29.87,
#   'cooling_load': 29.87,
#   'id': '76162233-2377-42bb-b66b-55ba23a6977d',
#   'prediction': 28.606842041015625},
#  {'_id': ObjectId('62ff9fad4fa515b53b6b6963'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 29.14,
#   'cooling_load': 29.58,
#   'id': '94c42ad4-3e24-40f7-8e5e-bc8658eafaf4',
#   'prediction': 28.606842041015625},
#  {'_id': ObjectId('62ff9fae4fa515b53b6b6964'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 28.09,
#   'cooling_load': 34.33,
#   'id': 'c3ab97c6-b9ce-4874-9182-4171cde70d46',
#   'prediction': 28.606842041015625},
#  {'_id': ObjectId('62ff9faf4fa515b53b6b6965'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 26.28,
#   'cooling_load': 30.89,
#   'id': '95d44d79-96fb-4cdc-b28a-acea6d685285',
#   'prediction': 26.28875160217285},
#  {'_id': ObjectId('62ff9fb04fa515b53b6b6966'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 26.91,
#   'cooling_load': 25.6,
#   'id': 'c743e782-c08d-4928-b423-4400d7181c02',
#   'prediction': 26.28875160217285},
#  {'_id': ObjectId('62ff9fb14fa515b53b6b6967'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 26.37,
#   'cooling_load': 27.03,
#   'id': '5e0da565-9acf-4204-801e-62b6d6f9cd3c',
#   'prediction': 26.28875160217285},
#  {'_id': ObjectId('62ff9fb24fa515b53b6b6968'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 25.27,
#   'cooling_load': 31.73,
#   'id': 'a5017eae-1f59-4099-95cc-1732d4840f31',
#   'prediction': 26.28875160217285},
#  {'_id': ObjectId('62ff9fb34fa515b53b6b6969'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 23.53,
#   'cooling_load': 27.31,
#   'id': '367523b1-8bc8-419f-a6c7-2eb73a807b53',
#   'prediction': 23.81591033935547},
#  {'_id': ObjectId('62ff9fb44fa515b53b6b696a'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 24.03,
#   'cooling_load': 24.91,
#   'id': '63366254-2bfb-47b9-909e-fe7671c65380',
#   'prediction': 23.81591033935547},
#  {'_id': ObjectId('62ff9fb54fa515b53b6b696b'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 23.54,
#   'cooling_load': 24.61,
#   'id': '41431fda-0f23-42e3-aa14-f2e58b71537c',
#   'prediction': 23.81591033935547},
#  {'_id': ObjectId('62ff9fb64fa515b53b6b696c'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 22.58,
#   'cooling_load': 28.51,
#   'id': '64ce8f82-8049-4ec9-9794-466a3242d633',
#   'prediction': 23.81591033935547},
#  {'_id': ObjectId('62ff9fb74fa515b53b6b696d'),
#   'relative_compactnes': 0.79,
#   'surface_area': 637.0,
#   'wall_area': 343.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 35.56,
#   'cooling_load': 41.68,
#   'id': '2cec8121-a38f-4278-a9b5-6fa54820cef5',
#   'prediction': 36.215267181396484},
#  {'_id': ObjectId('62ff9fb84fa515b53b6b696e'),
#   'relative_compactnes': 0.79,
#   'surface_area': 637.0,
#   'wall_area': 343.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 37.12,
#   'cooling_load': 35.28,
#   'id': '2d593e92-4a5d-4939-9a03-223d701d4899',
#   'prediction': 36.215267181396484},
#  {'_id': ObjectId('62ff9fb94fa515b53b6b696f'),
#   'relative_compactnes': 0.79,
#   'surface_area': 637.0,
#   'wall_area': 343.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 36.9,
#   'cooling_load': 34.43,
#   'id': '37f2f31f-4690-4f6d-a80e-62f28193d242',
#   'prediction': 36.215267181396484},
#  {'_id': ObjectId('62ff9fba4fa515b53b6b6970'),
#   'relative_compactnes': 0.79,
#   'surface_area': 637.0,
#   'wall_area': 343.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 35.94,
#   'cooling_load': 43.33,
#   'id': '941ba02f-7329-49da-a421-444a8ec0b2ec',
#   'prediction': 36.215267181396484},
#  {'_id': ObjectId('62ff9fbb4fa515b53b6b6971'),
#   'relative_compactnes': 0.76,
#   'surface_area': 661.5,
#   'wall_area': 416.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 32.96,
#   'cooling_load': 33.87,
#   'id': '483be9ea-e233-4687-89d3-5035eef17016',
#   'prediction': 32.756309509277344},
#  {'_id': ObjectId('62ff9fbc4fa515b53b6b6972'),
#   'relative_compactnes': 0.76,
#   'surface_area': 661.5,
#   'wall_area': 416.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 32.12,
#   'cooling_load': 34.07,
#   'id': '18b50744-a13c-40ac-90f0-25644752a71a',
#   'prediction': 32.756309509277344},
#  {'_id': ObjectId('62ff9fbd4fa515b53b6b6973'),
#   'relative_compactnes': 0.76,
#   'surface_area': 661.5,
#   'wall_area': 416.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 32.94,
#   'cooling_load': 34.14,
#   'id': 'fd38d613-91f7-4708-bcde-913be388025a',
#   'prediction': 32.756309509277344},
#  {'_id': ObjectId('62ff9fbe4fa515b53b6b6974'),
#   'relative_compactnes': 0.76,
#   'surface_area': 661.5,
#   'wall_area': 416.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 32.21,
#   'cooling_load': 33.67,
#   'id': '4bee0389-c035-4489-a5b3-117f86d6baa5',
#   'prediction': 32.756309509277344},
#  {'_id': ObjectId('62ff9fbf4fa515b53b6b6975'),
#   'relative_compactnes': 0.74,
#   'surface_area': 686.0,
#   'wall_area': 245.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 10.36,
#   'cooling_load': 13.43,
#   'id': '7df04fd2-079a-4073-bc20-1e94e1b77276',
#   'prediction': 10.338716506958008},
#  {'_id': ObjectId('62ff9fc04fa515b53b6b6976'),
#   'relative_compactnes': 0.74,
#   'surface_area': 686.0,
#   'wall_area': 245.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 10.43,
#   'cooling_load': 13.71,
#   'id': 'b105ab7b-9c40-4f96-becf-0cd57f45af0c',
#   'prediction': 10.338716506958008},
#  {'_id': ObjectId('62ff9fc14fa515b53b6b6977'),
#   'relative_compactnes': 0.74,
#   'surface_area': 686.0,
#   'wall_area': 245.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 10.36,
#   'cooling_load': 13.48,
#   'id': '974553dd-f517-4094-8f38-17e3045dd243',
#   'prediction': 10.338716506958008},
#  {'_id': ObjectId('62ff9fc34fa515b53b6b6978'),
#   'relative_compactnes': 0.74,
#   'surface_area': 686.0,
#   'wall_area': 245.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 10.39,
#   'cooling_load': 13.7,
#   'id': 'dfe839ff-4065-4a80-b9fe-f8a82340c9e8',
#   'prediction': 10.338716506958008},
#  {'_id': ObjectId('62ff9fc44fa515b53b6b6979'),
#   'relative_compactnes': 0.71,
#   'surface_area': 710.5,
#   'wall_area': 269.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 10.71,
#   'cooling_load': 13.8,
#   'id': '8fc1822b-2f71-421c-9676-4e93cfc2c27a',
#   'prediction': 10.591192245483398},
#  {'_id': ObjectId('62ff9fc54fa515b53b6b697a'),
#   'relative_compactnes': 0.71,
#   'surface_area': 710.5,
#   'wall_area': 269.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 10.8,
#   'cooling_load': 14.28,
#   'id': '91dae5dc-a464-4663-badc-60104a92a352',
#   'prediction': 10.591192245483398},
#  {'_id': ObjectId('62ff9fc64fa515b53b6b697b'),
#   'relative_compactnes': 0.71,
#   'surface_area': 710.5,
#   'wall_area': 269.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 10.7,
#   'cooling_load': 13.87,
#   'id': 'a6359615-f5d1-466c-b4a7-b5aa959843e1',
#   'prediction': 10.591192245483398},
#  {'_id': ObjectId('62ff9fc74fa515b53b6b697c'),
#   'relative_compactnes': 0.71,
#   'surface_area': 710.5,
#   'wall_area': 269.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 10.75,
#   'cooling_load': 14.27,
#   'id': '3b8775a9-8534-4824-97f8-0866ff79e4d5',
#   'prediction': 10.591192245483398},
#  {'_id': ObjectId('62ff9fc84fa515b53b6b697d'),
#   'relative_compactnes': 0.69,
#   'surface_area': 735.0,
#   'wall_area': 294.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.11,
#   'cooling_load': 14.28,
#   'id': '8f7849e3-70ce-40df-b24b-4c114f9b0a29',
#   'prediction': 11.241633415222168},
#  {'_id': ObjectId('62ff9fc94fa515b53b6b697e'),
#   'relative_compactnes': 0.69,
#   'surface_area': 735.0,
#   'wall_area': 294.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.13,
#   'cooling_load': 14.61,
#   'id': '861a3496-9c26-49bf-bc86-46e611efd715',
#   'prediction': 11.241633415222168},
#  {'_id': ObjectId('62ff9fca4fa515b53b6b697f'),
#   'relative_compactnes': 0.69,
#   'surface_area': 735.0,
#   'wall_area': 294.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.09,
#   'cooling_load': 14.3,
#   'id': '2de76ca4-f40c-4c36-93fc-905823ce117f',
#   'prediction': 11.241633415222168},
#  {'_id': ObjectId('62ff9fcb4fa515b53b6b6980'),
#   'relative_compactnes': 0.69,
#   'surface_area': 735.0,
#   'wall_area': 294.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.16,
#   'cooling_load': 14.45,
#   'id': 'adcdba11-b3b4-4d56-8eed-722ec4655b22',
#   'prediction': 11.241633415222168},
#  {'_id': ObjectId('62ff9fcc4fa515b53b6b6981'),
#   'relative_compactnes': 0.66,
#   'surface_area': 759.5,
#   'wall_area': 318.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.68,
#   'cooling_load': 13.9,
#   'id': '8ffb1243-32ae-4e59-a8be-ba7bfc958f97',
#   'prediction': 11.401554107666016},
#  {'_id': ObjectId('62ff9fcd4fa515b53b6b6982'),
#   'relative_compactnes': 0.66,
#   'surface_area': 759.5,
#   'wall_area': 318.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.69,
#   'cooling_load': 13.72,
#   'id': '5591fa55-1c5c-42c8-a479-4d895a870c5c',
#   'prediction': 11.401554107666016},
#  {'_id': ObjectId('62ff9fce4fa515b53b6b6983'),
#   'relative_compactnes': 0.66,
#   'surface_area': 759.5,
#   'wall_area': 318.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.7,
#   'cooling_load': 13.88,
#   'id': 'f0a1a53c-5983-4710-86a2-1d0b4376755b',
#   'prediction': 11.401554107666016},
#  {'_id': ObjectId('62ff9fcf4fa515b53b6b6984'),
#   'relative_compactnes': 0.66,
#   'surface_area': 759.5,
#   'wall_area': 318.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.69,
#   'cooling_load': 13.65,
#   'id': '1d79c9b8-4d4e-435c-afd5-b89ce8f6cba6',
#   'prediction': 11.401554107666016},
#  {'_id': ObjectId('62ff9fd04fa515b53b6b6985'),
#   'relative_compactnes': 0.64,
#   'surface_area': 784.0,
#   'wall_area': 343.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 15.41,
#   'cooling_load': 19.37,
#   'id': '51a57d4c-5f11-4dee-92ea-a7d44664aae9',
#   'prediction': 15.28026294708252},
#  {'_id': ObjectId('62ff9fd14fa515b53b6b6986'),
#   'relative_compactnes': 0.64,
#   'surface_area': 784.0,
#   'wall_area': 343.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 15.2,
#   'cooling_load': 19.43,
#   'id': '7fb5ac57-e39a-420f-8282-19e9f245d788',
#   'prediction': 15.28026294708252},
#  {'_id': ObjectId('62ff9fd24fa515b53b6b6987'),
#   'relative_compactnes': 0.64,
#   'surface_area': 784.0,
#   'wall_area': 343.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 15.42,
#   'cooling_load': 19.34,
#   'id': '2d1a09c2-514a-41b1-878f-ccebee0214d1',
#   'prediction': 15.28026294708252},
#  {'_id': ObjectId('62ff9fd34fa515b53b6b6988'),
#   'relative_compactnes': 0.64,
#   'surface_area': 784.0,
#   'wall_area': 343.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 15.21,
#   'cooling_load': 19.32,
#   'id': 'b595f155-bc7b-40ea-992e-229b54e423f2',
#   'prediction': 15.28026294708252},
#  {'_id': ObjectId('62ff9fd44fa515b53b6b6989'),
#   'relative_compactnes': 0.62,
#   'surface_area': 808.5,
#   'wall_area': 367.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 12.96,
#   'cooling_load': 14.34,
#   'id': 'b9f2290b-70f4-49fd-88a7-c5eb1c7b26f0',
#   'prediction': 13.033303260803223},
#  {'_id': ObjectId('62ff9fd54fa515b53b6b698a'),
#   'relative_compactnes': 0.62,
#   'surface_area': 808.5,
#   'wall_area': 367.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 12.97,
#   'cooling_load': 14.5,
#   'id': '320f4728-d2af-4b51-9bde-9a74804fb3d1',
#   'prediction': 13.033303260803223},
#  {'_id': ObjectId('62ff9fd64fa515b53b6b698b'),
#   'relative_compactnes': 0.62,
#   'surface_area': 808.5,
#   'wall_area': 367.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 12.93,
#   'cooling_load': 14.33,
#   'id': 'c75150e1-dc6e-4a7c-a3f4-82b16916d985',
#   'prediction': 13.033303260803223},
#  {'_id': ObjectId('62ff9fd74fa515b53b6b698c'),
#   'relative_compactnes': 0.62,
#   'surface_area': 808.5,
#   'wall_area': 367.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 13.02,
#   'cooling_load': 14.27,
#   'id': '45a578ee-98e7-4bc4-ab5e-0e3bceb99d5f',
#   'prediction': 13.033303260803223},
#  {'_id': ObjectId('62ff9fd94fa515b53b6b698d'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 24.29,
#   'cooling_load': 25.95,
#   'id': '9635e2e3-1129-4cf8-a07f-2ee565fc9da8',
#   'prediction': 24.408824920654297},
#  {'_id': ObjectId('62ff9fda4fa515b53b6b698e'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 24.31,
#   'cooling_load': 25.63,
#   'id': 'b6bec15c-da27-4d79-a573-0dffebedb8ae',
#   'prediction': 24.408824920654297},
#  {'_id': ObjectId('62ff9fdb4fa515b53b6b698f'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 24.13,
#   'cooling_load': 26.13,
#   'id': '5baba2fa-d419-4b5e-ad54-b2f487d0304d',
#   'prediction': 24.408824920654297},
#  {'_id': ObjectId('62ff9fdc4fa515b53b6b6990'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 24.25,
#   'cooling_load': 25.89,
#   'id': '6c18bead-62c4-4e0f-af16-d407bd786c91',
#   'prediction': 24.408824920654297},
#  {'_id': ObjectId('63031a54c8ab0a97a0b3ad67'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0',
#   'prediction': 15.69429874420166},
#  {'_id': ObjectId('63031b15a50e2da997e76b91'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0',
#   'prediction': 15.69429874420166},
#  {'_id': ObjectId('63031c93d954122326840dc0'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0',
#   'prediction': 15.69429874420166},
#  {'_id': ObjectId('63031cc7d954122326840dc1'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 15.55,
#   'cooling_load': 21.33,
#   'id': '905fdac2-5ec2-48ab-8b00-c8e6ef311f34',
#   'prediction': 15.652251243591309},
#  {'_id': ObjectId('63031cc8d954122326840dc2'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 15.55,
#   'cooling_load': 21.33,
#   'id': '8a7f651e-7b1a-4b05-821f-2183e31b037d',
#   'prediction': 15.652251243591309},
#  {'_id': ObjectId('63031cc9d954122326840dc3'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 15.55,
#   'cooling_load': 21.33,
#   'id': '6fd4586c-8493-4914-8cd0-337a2e850230',
#   'prediction': 15.652251243591309},
#  {'_id': ObjectId('63031ccad954122326840dc4'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 15.55,
#   'cooling_load': 21.33,
#   'id': 'ca1abca5-d0cd-4c48-b759-98fccfd98dd5',
#   'prediction': 15.652251243591309},
#  {'_id': ObjectId('63031ccbd954122326840dc5'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 20.84,
#   'cooling_load': 28.28,
#   'id': 'cea8c7e5-f729-4c87-a848-49b7edc4e352',
#   'prediction': 21.158700942993164},
#  {'_id': ObjectId('63031cccd954122326840dc6'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 21.46,
#   'cooling_load': 25.38,
#   'id': '959219fc-fbe2-4111-b12f-2ff3dd0c71b5',
#   'prediction': 21.158700942993164},
#  {'_id': ObjectId('63031ccdd954122326840dc7'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 20.71,
#   'cooling_load': 25.16,
#   'id': '6ce0c3ef-097f-4da9-a739-c32639bbc40c',
#   'prediction': 21.158700942993164},
#  {'_id': ObjectId('63031cced954122326840dc8'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 19.68,
#   'cooling_load': 29.6,
#   'id': '0990187d-7b14-432d-9765-c8d08e2e7dd4',
#   'prediction': 21.158700942993164},
#  {'_id': ObjectId('63031ccfd954122326840dc9'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 19.5,
#   'cooling_load': 27.3,
#   'id': 'a3e5d2a3-0526-4655-b8b3-d1e4c8aa8ef7',
#   'prediction': 18.813987731933594},
#  {'_id': ObjectId('63031cd0d954122326840dca'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 19.95,
#   'cooling_load': 21.97,
#   'id': '17a29dd6-8747-47e8-a2f9-bcc763ad94dd',
#   'prediction': 18.813987731933594},
#  {'_id': ObjectId('63031cd1d954122326840dcb'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 19.34,
#   'cooling_load': 23.49,
#   'id': '5302ebe5-942a-4592-b0bb-a7724d96860f',
#   'prediction': 18.813987731933594},
#  {'_id': ObjectId('63031cd2d954122326840dcc'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 18.31,
#   'cooling_load': 27.87,
#   'id': '996876d3-f5d8-4d65-a8ce-520b66e7d998',
#   'prediction': 18.813987731933594},
#  {'_id': ObjectId('63031cd3d954122326840dcd'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 17.05,
#   'cooling_load': 23.77,
#   'id': '38b95403-2352-435f-b048-086ec4f243bc',
#   'prediction': 16.802690505981445},
#  {'_id': ObjectId('63031cd4d954122326840dce'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.0,
#   'glazing_area_distribution': '0.0',
#   'heating_load': 17.41,
#   'cooling_load': 21.46,
#   'id': '27b223bf-4abf-464a-8798-48e0ad0f8802',
#   'prediction': 16.802690505981445},
#  {'_id': ObjectId('63031cd5d954122326840dcf'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '4.0',
# ...
#   'surface_area': 735.0,
#   'wall_area': 294.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.11,
#   'cooling_load': 14.28,
#   'id': '3019ce1c-5f52-4ba5-ab82-501261f7dcbd',
#   'prediction': 11.241633415222168},
#  {'_id': ObjectId('630321d8d954122326841112'),
#   'relative_compactnes': 0.69,
#   'surface_area': 735.0,
#   'wall_area': 294.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.13,
#   'cooling_load': 14.61,
#   'id': '9f79bc7e-e0d7-4f56-87f6-7e7f8555729d',
#   'prediction': 11.241633415222168},
#  {'_id': ObjectId('630321d9d954122326841113'),
#   'relative_compactnes': 0.69,
#   'surface_area': 735.0,
#   'wall_area': 294.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.09,
#   'cooling_load': 14.3,
#   'id': 'a3c55034-5de1-46e2-9a45-1c51efa74db1',
#   'prediction': 11.241633415222168},
#  {'_id': ObjectId('630321dad954122326841114'),
#   'relative_compactnes': 0.69,
#   'surface_area': 735.0,
#   'wall_area': 294.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.16,
#   'cooling_load': 14.45,
#   'id': 'a2a2fb48-070c-4518-a7ad-964c8d039dab',
#   'prediction': 11.241633415222168},
#  {'_id': ObjectId('630321dbd954122326841115'),
#   'relative_compactnes': 0.66,
#   'surface_area': 759.5,
#   'wall_area': 318.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.68,
#   'cooling_load': 13.9,
#   'id': '472458e3-1c92-4831-b3a8-7ced00f25270',
#   'prediction': 11.401554107666016},
#  {'_id': ObjectId('630321dcd954122326841116'),
#   'relative_compactnes': 0.66,
#   'surface_area': 759.5,
#   'wall_area': 318.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.69,
#   'cooling_load': 13.72,
#   'id': '79703f90-0ecc-4a73-8ac7-ee8a8af95543',
#   'prediction': 11.401554107666016},
#  {'_id': ObjectId('630321ddd954122326841117'),
#   'relative_compactnes': 0.66,
#   'surface_area': 759.5,
#   'wall_area': 318.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.7,
#   'cooling_load': 13.88,
#   'id': '97e144b5-2bb1-46bb-be2f-c107220fcd26',
#   'prediction': 11.401554107666016},
#  {'_id': ObjectId('630321ded954122326841118'),
#   'relative_compactnes': 0.66,
#   'surface_area': 759.5,
#   'wall_area': 318.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 11.69,
#   'cooling_load': 13.65,
#   'id': 'cd063723-c5f9-4b8f-87df-04642bc0d81f',
#   'prediction': 11.401554107666016},
#  {'_id': ObjectId('630321dfd954122326841119'),
#   'relative_compactnes': 0.64,
#   'surface_area': 784.0,
#   'wall_area': 343.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 15.41,
#   'cooling_load': 19.37,
#   'id': '71067388-e591-46a2-b6ab-f69e1abc243c',
#   'prediction': 15.28026294708252},
#  {'_id': ObjectId('630321e0d95412232684111a'),
#   'relative_compactnes': 0.64,
#   'surface_area': 784.0,
#   'wall_area': 343.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 15.2,
#   'cooling_load': 19.43,
#   'id': '3f2b1451-4dc8-4eb4-819b-db0e6a24f218',
#   'prediction': 15.28026294708252},
#  {'_id': ObjectId('630321e2d95412232684111b'),
#   'relative_compactnes': 0.64,
#   'surface_area': 784.0,
#   'wall_area': 343.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 15.42,
#   'cooling_load': 19.34,
#   'id': '3d18eab0-9310-41cc-a9f8-f99a933fd6f1',
#   'prediction': 15.28026294708252},
#  {'_id': ObjectId('630321e3d95412232684111c'),
#   'relative_compactnes': 0.64,
#   'surface_area': 784.0,
#   'wall_area': 343.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 15.21,
#   'cooling_load': 19.32,
#   'id': '913f0b9b-8408-4879-8813-2331f987661d',
#   'prediction': 15.28026294708252},
#  {'_id': ObjectId('630321e4d95412232684111d'),
#   'relative_compactnes': 0.62,
#   'surface_area': 808.5,
#   'wall_area': 367.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 12.96,
#   'cooling_load': 14.34,
#   'id': 'be728ba5-3d9a-4f7c-9086-e89a4dd0ad1b',
#   'prediction': 13.033303260803223},
#  {'_id': ObjectId('630321e5d95412232684111e'),
#   'relative_compactnes': 0.62,
#   'surface_area': 808.5,
#   'wall_area': 367.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 12.97,
#   'cooling_load': 14.5,
#   'id': '4f696a8e-4ef5-42ef-8f32-d40cfb9a96fa',
#   'prediction': 13.033303260803223},
#  {'_id': ObjectId('630321e6d95412232684111f'),
#   'relative_compactnes': 0.62,
#   'surface_area': 808.5,
#   'wall_area': 367.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 12.93,
#   'cooling_load': 14.33,
#   'id': '2189ee19-99db-463c-b6a8-b8c8a1d24adc',
#   'prediction': 13.033303260803223},
#  {'_id': ObjectId('630321e7d954122326841120'),
#   'relative_compactnes': 0.62,
#   'surface_area': 808.5,
#   'wall_area': 367.5,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '1.0',
#   'heating_load': 13.02,
#   'cooling_load': 14.27,
#   'id': 'b1b9de2a-bfa9-4939-90e2-4ebdd9e70644',
#   'prediction': 13.033303260803223},
#  {'_id': ObjectId('630321e8d954122326841121'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 24.29,
#   'cooling_load': 25.95,
#   'id': 'a9ab714e-cec6-46ad-960d-7ad60e437bc8',
#   'prediction': 24.408824920654297},
#  {'_id': ObjectId('630321e9d954122326841122'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 24.31,
#   'cooling_load': 25.63,
#   'id': '27a7f24f-8aff-4338-9443-e2ad6c91c41f',
#   'prediction': 24.408824920654297},
#  {'_id': ObjectId('630321ead954122326841123'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 24.13,
#   'cooling_load': 26.13,
#   'id': 'baaebbe3-0fe7-4b4d-9a85-c2cb032d4541',
#   'prediction': 24.408824920654297},
#  {'_id': ObjectId('630321ebd954122326841124'),
#   'relative_compactnes': 0.98,
#   'surface_area': 514.5,
#   'wall_area': 294.0,
#   'roof_area': 110.25,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 24.25,
#   'cooling_load': 25.89,
#   'id': 'c6f339fd-cb4c-4c1f-bf03-ccb7dac1fbfd',
#   'prediction': 24.408824920654297},
#  {'_id': ObjectId('630321ecd954122326841125'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 28.88,
#   'cooling_load': 32.54,
#   'id': '89c4c017-bc0c-4a75-977a-376db809c758',
#   'prediction': 28.606842041015625},
#  {'_id': ObjectId('630321edd954122326841126'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 29.68,
#   'cooling_load': 29.44,
#   'id': 'd1df1788-1c20-448d-9a6b-04fa30532e01',
#   'prediction': 28.606842041015625},
#  {'_id': ObjectId('630321eed954122326841127'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 28.83,
#   'cooling_load': 29.36,
#   'id': '2c4d95c9-cf03-4476-ad2d-da512e6f4560',
#   'prediction': 28.606842041015625},
#  {'_id': ObjectId('630321efd954122326841128'),
#   'relative_compactnes': 0.9,
#   'surface_area': 563.5,
#   'wall_area': 318.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 27.9,
#   'cooling_load': 34.2,
#   'id': '2d3cf88b-63b9-44d4-9afa-0748b2ca41c3',
#   'prediction': 28.606842041015625},
#  {'_id': ObjectId('630321f0d954122326841129'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 26.48,
#   'cooling_load': 30.91,
#   'id': 'aab012d2-3955-4a21-887e-d0c6f64dd03e',
#   'prediction': 26.28875160217285},
#  {'_id': ObjectId('630321f1d95412232684112a'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 27.02,
#   'cooling_load': 25.63,
#   'id': 'ccd001af-62fa-40b8-953b-2070680d1fb4',
#   'prediction': 26.28875160217285},
#  {'_id': ObjectId('630321f2d95412232684112b'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 26.33,
#   'cooling_load': 27.36,
#   'id': 'f0c3cec3-e243-430c-93c8-6071d595468b',
#   'prediction': 26.28875160217285},
#  {'_id': ObjectId('630321f3d95412232684112c'),
#   'relative_compactnes': 0.86,
#   'surface_area': 588.0,
#   'wall_area': 294.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 25.36,
#   'cooling_load': 31.9,
#   'id': 'd6d9356e-fdc6-4a8c-9f15-c9cfe2e310dd',
#   'prediction': 26.28875160217285},
#  {'_id': ObjectId('630321f5d95412232684112d'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 23.75,
#   'cooling_load': 27.38,
#   'id': 'ec168db6-1f99-4927-b45f-7348a6a57490',
#   'prediction': 23.81591033935547},
#  {'_id': ObjectId('630321f6d95412232684112e'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 24.23,
#   'cooling_load': 25.02,
#   'id': '1f039f06-11b9-41ff-83fe-ea03d411c1aa',
#   'prediction': 23.81591033935547},
#  {'_id': ObjectId('630321f7d95412232684112f'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 23.67,
#   'cooling_load': 24.8,
#   'id': 'a51b7ca2-b8bc-4b8d-874b-5aa0360eea93',
#   'prediction': 23.81591033935547},
#  {'_id': ObjectId('630321f8d954122326841130'),
#   'relative_compactnes': 0.82,
#   'surface_area': 612.5,
#   'wall_area': 318.5,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 22.79,
#   'cooling_load': 28.79,
#   'id': 'b087075b-9448-4aca-9810-fe2db85c458c',
#   'prediction': 23.81591033935547},
#  {'_id': ObjectId('630321f9d954122326841131'),
#   'relative_compactnes': 0.79,
#   'surface_area': 637.0,
#   'wall_area': 343.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 35.65,
#   'cooling_load': 41.07,
#   'id': 'cd4b4159-b4e4-40e5-8a69-0d75572691c3',
#   'prediction': 36.215267181396484},
#  {'_id': ObjectId('630321fad954122326841132'),
#   'relative_compactnes': 0.79,
#   'surface_area': 637.0,
#   'wall_area': 343.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 37.26,
#   'cooling_load': 34.62,
#   'id': 'ccb6f1b2-21c8-4f81-84ea-b773db41bb04',
#   'prediction': 36.215267181396484},
#  {'_id': ObjectId('630321fbd954122326841133'),
#   'relative_compactnes': 0.79,
#   'surface_area': 637.0,
#   'wall_area': 343.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 36.97,
#   'cooling_load': 33.87,
#   'id': '5c257b0c-1fd4-4e62-8c17-5dbead75c296',
#   'prediction': 36.215267181396484},
#  {'_id': ObjectId('630321fcd954122326841134'),
#   'relative_compactnes': 0.79,
#   'surface_area': 637.0,
#   'wall_area': 343.0,
#   'roof_area': 147.0,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 36.03,
#   'cooling_load': 42.86,
#   'id': 'a6ca45c3-c293-4f17-a453-accfc5ab322f',
#   'prediction': 36.215267181396484},
#  {'_id': ObjectId('630321fdd954122326841135'),
#   'relative_compactnes': 0.76,
#   'surface_area': 661.5,
#   'wall_area': 416.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 33.16,
#   'cooling_load': 33.91,
#   'id': '7c12818f-b36a-4cb8-9d5e-351323223e21',
#   'prediction': 32.756309509277344},
#  {'_id': ObjectId('630321fed954122326841136'),
#   'relative_compactnes': 0.76,
#   'surface_area': 661.5,
#   'wall_area': 416.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '3.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 32.4,
#   'cooling_load': 34.07,
#   'id': 'c25c160a-f486-49df-a575-a40b7d4f5561',
#   'prediction': 32.756309509277344},
#  {'_id': ObjectId('630321ffd954122326841137'),
#   'relative_compactnes': 0.76,
#   'surface_area': 661.5,
#   'wall_area': 416.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '4.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 33.12,
#   'cooling_load': 34.17,
#   'id': 'c56cd257-6758-43b6-9e69-2d7da992b31b',
#   'prediction': 32.756309509277344},
#  {'_id': ObjectId('63032200d954122326841138'),
#   'relative_compactnes': 0.76,
#   'surface_area': 661.5,
#   'wall_area': 416.5,
#   'roof_area': 122.5,
#   'overall_height': 7.0,
#   'orientation': '5.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 32.41,
#   'cooling_load': 33.78,
#   'id': '4cda4297-4efe-44b0-8512-cc9cee82903c',
#   'prediction': 32.756309509277344},
#  {'_id': ObjectId('63032201d954122326841139'),
#   'relative_compactnes': 0.74,
#   'surface_area': 686.0,
#   'wall_area': 245.0,
#   'roof_area': 220.5,
#   'overall_height': 3.5,
#   'orientation': '2.0',
#   'glazing_area': 0.1,
#   'glazing_area_distribution': '2.0',
#   'heating_load': 10.42,
#   'cooling_load': 13.39,
#   'id': '96f5adfb-5d78-4d6b-9f9a-682e25126707',
#   'prediction': 10.338716506958008},
#  ...]

# %%
data[0]
# Out:
# {'_id': ObjectId('62ff9ae7a4c054ef37b7098e'),
#  'relative_compactnes': 0.98,
#  'surface_area': 514.5,
#  'wall_area': 294.0,
#  'roof_area': 110.25,
#  'overall_height': 7.0,
#  'orientation': '2',
#  'glazing_area': 0.0,
#  'glazing_area_distribution': '0',
#  'prediction': 15.69429874420166}

# %%
# !python -V
# Out:
# Python 3.9.7

# %%
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (8.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from pyarrow) (1.21.2)

# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (1.26.0)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (4.10.0)
# Requirement already satisfied: packaging in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (21.3)
# Requirement already satisfied: gitpython>=2.1.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (3.1.27)
# Requirement already satisfied: pytz in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (2021.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (5.4.1)
# Requirement already satisfied: sqlparse>=0.3.1 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (0.4.2)
# Requirement already satisfied: sqlalchemy in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (1.4.29)
# Requirement already satisfied: gunicorn in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (20.1.0)
# Requirement already satisfied: prometheus-flask-exporter in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (0.20.1)
# Requirement already satisfied: protobuf>=3.7.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (3.17.2)
# Requirement already satisfied: querystring-parser in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: scipy in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (1.7.3)
# Requirement already satisfied: databricks-cli>=0.8.7 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (0.16.6)
# Requirement already satisfied: docker>=4.0.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (5.0.3)
# Requirement already satisfied: Flask in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (2.0.2)
# Requirement already satisfied: alembic in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (1.7.7)
# Requirement already satisfied: click>=7.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (8.0.4)
# Requirement already satisfied: cloudpickle in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (2.1.0)
# Requirement already satisfied: entrypoints in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (0.3)
# Requirement already satisfied: numpy in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (1.21.2)
# Requirement already satisfied: requests>=2.17.3 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (2.27.1)
# Requirement already satisfied: pandas in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from mlflow) (1.3.5)
# Requirement already satisfied: pyjwt>=1.7.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from databricks-cli>=0.8.7->mlflow) (2.3.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from databricks-cli>=0.8.7->mlflow) (3.2.0)
# Requirement already satisfied: six>=1.10.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from databricks-cli>=0.8.7->mlflow) (1.16.0)
# Requirement already satisfied: tabulate>=0.7.7 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from databricks-cli>=0.8.7->mlflow) (0.8.9)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from docker>=4.0.0->mlflow) (1.2.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from gitpython>=2.1.0->mlflow) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow) (3.7.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from requests>=2.17.3->mlflow) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from requests>=2.17.3->mlflow) (3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from requests>=2.17.3->mlflow) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from requests>=2.17.3->mlflow) (2021.10.8)
# Requirement already satisfied: Mako in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from alembic->mlflow) (1.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from sqlalchemy->mlflow) (1.1.2)
# Requirement already satisfied: Jinja2>=3.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from Flask->mlflow) (3.0.3)
# Requirement already satisfied: Werkzeug>=2.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from Flask->mlflow) (2.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from Flask->mlflow) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from Jinja2>=3.0->Flask->mlflow) (2.0.1)
# Requirement already satisfied: setuptools>=3.0 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from gunicorn->mlflow) (58.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from packaging->mlflow) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from pandas->mlflow) (2.8.2)
# Requirement already satisfied: prometheus-client in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from prometheus-flask-exporter->mlflow) (0.12.0)

# %% [markdown]
# # Setup

# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
# !export MLFLOW_TRACKING_URI sqlite:///mlflow.db
# Out:
# /bin/bash: line 0: export: `sqlite:///mlflow.db': not a valid identifier

# %%
#from mlflow.tracking import MlflowClient
#MlflowClient
#tracking_uri = MlflowClient.mlflow_tracking_uri

# %%
# import mlflow
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment_2")#, artifact_location='.') # mlflow checks, if this experiment exists, if not it is created, if not runs are  appended
#mlflow.set_tracking_uri("nyc-test") #creates local tracking folder
#mlflow.set_experiment("/test")
print("Tracking URI:", mlflow.tracking.get_tracking_uri())
# Out:
# Tracking URI: sqlite:///mlflow.db

# %% [markdown]
# # Read the Data

# %%
df = pd.read_parquet('../data/green_tripdata_2021-01.parquet')

df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

df = df[(df.duration >= 1) & (df.duration <= 60)]

categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df[categorical] = df[categorical].astype(str)

# %% [markdown]
# # Data Preparation

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = df[target].values

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('../data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('../data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.75871520559622

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %% [markdown]
# # Model - Experiment Tracking with MLflow

# %%
with mlflow.start_run(run_name="test_run_1") as run:
    
    mlflow.set_tag("developer", "frauke")
    
    mlflow.log_param("train-data-path", "../data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "../data/green_tripdata_2021-02.parquet")
    
    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)

    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

# %% [markdown]
# # Second Model - with Hyperparameter Tuning

# %%
# !pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (0.2.7)
# Requirement already satisfied: numpy in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from hyperopt) (1.21.2)
# Requirement already satisfied: tqdm in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from hyperopt) (4.63.1)
# Requirement already satisfied: cloudpickle in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from hyperopt) (2.1.0)
# Requirement already satisfied: future in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from hyperopt) (0.18.2)
# Requirement already satisfied: scipy in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from hyperopt) (1.7.3)
# Requirement already satisfied: py4j in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from hyperopt) (0.10.9.5)
# Requirement already satisfied: six in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from hyperopt) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from hyperopt) (2.8.2)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (1.5.2)
# Requirement already satisfied: scipy in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from xgboost) (1.7.3)
# Requirement already satisfied: numpy in /home/frauke/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages (from xgboost) (1.21.2)

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        # log paramters in mlflow
        mlflow.log_params(params)
        booster = xgb.train(
            # paramters are passed to xgboost
            params=params,
            # training on train data
            dtrain=train,
            # set boosting rounds
            num_boost_round=100,
            # validation is done on validation dataset
            evals=[(valid, 'validation')],
            # if model does not improve for 50 methods->stop
            early_stopping_rounds=50
        )
        # make predictions
        y_pred = booster.predict(valid)
        # calculate error
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        # log metric
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
# define the search space, i.e. the range of parameters for hyperparamter tuning
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0), #[exp(-3), exp(0)] = [0.05, 1]
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

# fmin method tries to minimize the metric
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [15:27:24] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:12.76520
# [1]	validation-rmse:9.08599
# [2]	validation-rmse:7.64047
# [3]	validation-rmse:7.09458
# [4]	validation-rmse:6.88028
# [5]	validation-rmse:6.78690
# [6]	validation-rmse:6.73811
# [7]	validation-rmse:6.71413
# [8]	validation-rmse:6.70266
# [9]	validation-rmse:6.69642
# [10]	validation-rmse:6.69260
# [11]	validation-rmse:6.68766
# [12]	validation-rmse:6.68579
# [13]	validation-rmse:6.68322
# [14]	validation-rmse:6.68191
# [15]	validation-rmse:6.68041
# [16]	validation-rmse:6.67908
# [17]	validation-rmse:6.67836
# [18]	validation-rmse:6.67697
# [19]	validation-rmse:6.67615
# [20]	validation-rmse:6.67543
# [21]	validation-rmse:6.67397
# [22]	validation-rmse:6.67309
# [23]	validation-rmse:6.67204
# [24]	validation-rmse:6.66995
# [25]	validation-rmse:6.66918
# [26]	validation-rmse:6.66916
# [27]	validation-rmse:6.66840
# [28]	validation-rmse:6.66803
# [29]	validation-rmse:6.66698
# [30]	validation-rmse:6.66649
# [31]	validation-rmse:6.66646
# [32]	validation-rmse:6.66600
# [33]	validation-rmse:6.66502
# [34]	validation-rmse:6.66467
# [35]	validation-rmse:6.66450
# [36]	validation-rmse:6.66193
# [37]	validation-rmse:6.66032
# [38]	validation-rmse:6.65940
# [39]	validation-rmse:6.65960
# [40]	validation-rmse:6.65901
# [41]	validation-rmse:6.65923
# [42]	validation-rmse:6.65847
# [43]	validation-rmse:6.65817
# [44]	validation-rmse:6.65749
# [45]	validation-rmse:6.65769
# [46]	validation-rmse:6.65718
# [47]	validation-rmse:6.65611
# [48]	validation-rmse:6.65592
# [49]	validation-rmse:6.65623
# [50]	validation-rmse:6.65525
# [51]	validation-rmse:6.65491
# [52]	validation-rmse:6.65510
# [53]	validation-rmse:6.65448
# [54]	validation-rmse:6.65466
# [55]	validation-rmse:6.65430
# [56]	validation-rmse:6.65429
# [57]	validation-rmse:6.65416
# [58]	validation-rmse:6.65344
# [59]	validation-rmse:6.65321
# [60]	validation-rmse:6.65294
# [61]	validation-rmse:6.65375
# [62]	validation-rmse:6.65333
# [63]	validation-rmse:6.65301
# [64]	validation-rmse:6.65299
# [65]	validation-rmse:6.65270
# [66]	validation-rmse:6.65299
# [67]	validation-rmse:6.65265
# [68]	validation-rmse:6.65279
# [69]	validation-rmse:6.65300
# [70]	validation-rmse:6.65355
# [71]	validation-rmse:6.65325
# [72]	validation-rmse:6.65309
# [73]	validation-rmse:6.65283
# [74]	validation-rmse:6.65207
# [75]	validation-rmse:6.65209
# [76]	validation-rmse:6.65225
# [77]	validation-rmse:6.65215
# [78]	validation-rmse:6.65216
# [79]	validation-rmse:6.65194
# [80]	validation-rmse:6.65204
# [81]	validation-rmse:6.65168
# [82]	validation-rmse:6.65166
# [83]	validation-rmse:6.65133
# [84]	validation-rmse:6.65092
# [85]	validation-rmse:6.65098
# [86]	validation-rmse:6.65023
# [87]	validation-rmse:6.65023
# [88]	validation-rmse:6.65033
# [89]	validation-rmse:6.65069
# [90]	validation-rmse:6.65063
# [91]	validation-rmse:6.65048
# [92]	validation-rmse:6.65050
# [93]	validation-rmse:6.65030
# [94]	validation-rmse:6.64994
# [95]	validation-rmse:6.64992
# [96]	validation-rmse:6.64955
# [97]	validation-rmse:6.64926
# [98]	validation-rmse:6.64921
# [99]	validation-rmse:6.64853
# [15:27:30] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.13787
# [1]	validation-rmse:12.74177
# [2]	validation-rmse:10.48366
# [3]	validation-rmse:9.01063
# [4]	validation-rmse:8.09718
# [5]	validation-rmse:7.53502
# [6]	validation-rmse:7.18253
# [7]	validation-rmse:6.95861
# [8]	validation-rmse:6.82772
# [9]	validation-rmse:6.73198
# [10]	validation-rmse:6.67362
# [11]	validation-rmse:6.63366
# [12]	validation-rmse:6.60251
# [13]	validation-rmse:6.58314
# [14]	validation-rmse:6.56963
# [15]	validation-rmse:6.55574
# [16]	validation-rmse:6.54830
# [17]	validation-rmse:6.54263
# [18]	validation-rmse:6.53728
# [19]	validation-rmse:6.53268
# [20]	validation-rmse:6.52786
# [21]	validation-rmse:6.52325
# [22]	validation-rmse:6.52026
# [23]	validation-rmse:6.51825
# [24]	validation-rmse:6.51618
# [25]	validation-rmse:6.51360
# [26]	validation-rmse:6.51226
# [27]	validation-rmse:6.51021
# [28]	validation-rmse:6.50855
# [29]	validation-rmse:6.50638
# [30]	validation-rmse:6.50522
# [31]	validation-rmse:6.50387
# [32]	validation-rmse:6.50256
# [33]	validation-rmse:6.50200
# [34]	validation-rmse:6.50137
# [35]	validation-rmse:6.50066
# [36]	validation-rmse:6.49860
# [37]	validation-rmse:6.49687
# [38]	validation-rmse:6.49589
# [39]	validation-rmse:6.49336
# [40]	validation-rmse:6.49380
# [41]	validation-rmse:6.49296
# [42]	validation-rmse:6.49250
# [43]	validation-rmse:6.49199
# [44]	validation-rmse:6.49092
# [45]	validation-rmse:6.49088
# [46]	validation-rmse:6.48952
# [47]	validation-rmse:6.48877
# [48]	validation-rmse:6.48757
# [49]	validation-rmse:6.48656
# [50]	validation-rmse:6.48599
# [51]	validation-rmse:6.48513
# [52]	validation-rmse:6.48440
# [53]	validation-rmse:6.48398
# [54]	validation-rmse:6.48292
# [55]	validation-rmse:6.48288
# [56]	validation-rmse:6.48224
# [57]	validation-rmse:6.48212
# [58]	validation-rmse:6.48084
# [59]	validation-rmse:6.48032
# [60]	validation-rmse:6.47968
# [61]	validation-rmse:6.47949
# [62]	validation-rmse:6.47875
# [63]	validation-rmse:6.47828
# [64]	validation-rmse:6.47845
# [65]	validation-rmse:6.47743
# [66]	validation-rmse:6.47698
# [67]	validation-rmse:6.47640
# [68]	validation-rmse:6.47642
# [69]	validation-rmse:6.47585
# [70]	validation-rmse:6.47579
# [71]	validation-rmse:6.47586
# [72]	validation-rmse:6.47571
# [73]	validation-rmse:6.47391
# [74]	validation-rmse:6.47318
# [75]	validation-rmse:6.47300
# [76]	validation-rmse:6.47325
# [77]	validation-rmse:6.47319
# [78]	validation-rmse:6.47305
# [79]	validation-rmse:6.47270
# [80]	validation-rmse:6.47288
# [81]	validation-rmse:6.47195
# [82]	validation-rmse:6.47178
# [83]	validation-rmse:6.47092
# [84]	validation-rmse:6.46990
# [85]	validation-rmse:6.47142
# [86]	validation-rmse:6.46998
# [87]	validation-rmse:6.46939
# [88]	validation-rmse:6.46905
# [89]	validation-rmse:6.46943
# [90]	validation-rmse:6.46967
# [91]	validation-rmse:6.46914
# [92]	validation-rmse:6.46887
# [93]	validation-rmse:6.46804
# [94]	validation-rmse:6.46689
# [95]	validation-rmse:6.46590
# [96]	validation-rmse:6.46576
# [97]	validation-rmse:6.46538
# [98]	validation-rmse:6.46535
# [99]	validation-rmse:6.46591
# [15:27:53] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17.99006
# [1]	validation-rmse:15.43239
# [2]	validation-rmse:13.40534
# [3]	validation-rmse:11.81625
# [4]	validation-rmse:10.58233
# [5]	validation-rmse:9.63268
# [6]	validation-rmse:8.91128
# [7]	validation-rmse:8.36732
# [8]	validation-rmse:7.95820
# [9]	validation-rmse:7.65443
# [10]	validation-rmse:7.42660
# [11]	validation-rmse:7.25547
# [12]	validation-rmse:7.12774
# [13]	validation-rmse:7.02937
# [14]	validation-rmse:6.95480
# [15]	validation-rmse:6.89646
# [16]	validation-rmse:6.85006
# [17]	validation-rmse:6.81405
# [18]	validation-rmse:6.78621
# [19]	validation-rmse:6.76246
# [20]	validation-rmse:6.74485
# [21]	validation-rmse:6.73041
# [22]	validation-rmse:6.71844
# [23]	validation-rmse:6.70806
# [24]	validation-rmse:6.69928
# [25]	validation-rmse:6.69198
# [26]	validation-rmse:6.68633
# [27]	validation-rmse:6.68228
# [28]	validation-rmse:6.67773
# [29]	validation-rmse:6.67481
# [30]	validation-rmse:6.67162
# [31]	validation-rmse:6.66948
# [32]	validation-rmse:6.66763
# [33]	validation-rmse:6.66580
# [34]	validation-rmse:6.66445
# [35]	validation-rmse:6.66302
# [36]	validation-rmse:6.66196
# [37]	validation-rmse:6.66053
# [38]	validation-rmse:6.65952
# [39]	validation-rmse:6.65868
# [40]	validation-rmse:6.65786
# [41]	validation-rmse:6.65686
# [42]	validation-rmse:6.65605
# [43]	validation-rmse:6.65551
# [44]	validation-rmse:6.65499
# [45]	validation-rmse:6.65404
# [46]	validation-rmse:6.65332
# [47]	validation-rmse:6.65273
# [48]	validation-rmse:6.65213
# [49]	validation-rmse:6.65198
# [50]	validation-rmse:6.65154
# [51]	validation-rmse:6.65114
# [52]	validation-rmse:6.65071
# [53]	validation-rmse:6.65013
# [54]	validation-rmse:6.64957
# [55]	validation-rmse:6.64940
# [56]	validation-rmse:6.64911
# [57]	validation-rmse:6.64868
# [58]	validation-rmse:6.64809
# [59]	validation-rmse:6.64640
# [60]	validation-rmse:6.64607
# [61]	validation-rmse:6.64565
# [62]	validation-rmse:6.64509
# [63]	validation-rmse:6.64475
# [64]	validation-rmse:6.64363
# [65]	validation-rmse:6.64358
# [66]	validation-rmse:6.64345
# [67]	validation-rmse:6.64324
# [68]	validation-rmse:6.64234
# [69]	validation-rmse:6.64209
# [70]	validation-rmse:6.64132
# [71]	validation-rmse:6.64103
# [72]	validation-rmse:6.64088
# [73]	validation-rmse:6.64033
# [74]	validation-rmse:6.64030
# [75]	validation-rmse:6.63995
# [76]	validation-rmse:6.63967
# [77]	validation-rmse:6.63920
# [78]	validation-rmse:6.63919
# [79]	validation-rmse:6.63890
# [80]	validation-rmse:6.63863
# [81]	validation-rmse:6.63838
# [82]	validation-rmse:6.63799
# [83]	validation-rmse:6.63730
# [84]	validation-rmse:6.63699
# [85]	validation-rmse:6.63689
# [86]	validation-rmse:6.63640
# [87]	validation-rmse:6.63615
# [88]	validation-rmse:6.63539
# [89]	validation-rmse:6.63526
# [90]	validation-rmse:6.63509
# [91]	validation-rmse:6.63474
# [92]	validation-rmse:6.63435
# [93]	validation-rmse:6.63403
# [94]	validation-rmse:6.63406
# [95]	validation-rmse:6.63376
# [96]	validation-rmse:6.63349
# [97]	validation-rmse:6.63345
# [98]	validation-rmse:6.63320
# [99]	validation-rmse:6.63308
# [15:28:03] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:12.82312
# [1]	validation-rmse:9.08878
# [2]	validation-rmse:7.57494
# [3]	validation-rmse:6.98290
# [4]	validation-rmse:6.74228
# [5]	validation-rmse:6.63329
# [6]	validation-rmse:6.58423
# [7]	validation-rmse:6.55092
# [8]	validation-rmse:6.53277
# [9]	validation-rmse:6.52584
# [10]	validation-rmse:6.51767
# [11]	validation-rmse:6.51214
# [12]	validation-rmse:6.50772
# [13]	validation-rmse:6.49994
# [14]	validation-rmse:6.49562
# [15]	validation-rmse:6.49277
# [16]	validation-rmse:6.48934
# [17]	validation-rmse:6.48646
# [18]	validation-rmse:6.48220
# [19]	validation-rmse:6.47935
# [20]	validation-rmse:6.47601
# [21]	validation-rmse:6.46939
# [22]	validation-rmse:6.46773
# [23]	validation-rmse:6.46560
# [24]	validation-rmse:6.46284
# [25]	validation-rmse:6.46124
# [26]	validation-rmse:6.46014
# [27]	validation-rmse:6.45757
# [28]	validation-rmse:6.45571
# [29]	validation-rmse:6.45274
# [30]	validation-rmse:6.45051
# [31]	validation-rmse:6.44961
# [32]	validation-rmse:6.44782
# [33]	validation-rmse:6.44706
# [34]	validation-rmse:6.44591
# [35]	validation-rmse:6.44435
# [36]	validation-rmse:6.44274
# [37]	validation-rmse:6.44038
# [38]	validation-rmse:6.43964
# [39]	validation-rmse:6.43830
# [40]	validation-rmse:6.43774
# [41]	validation-rmse:6.43597
# [42]	validation-rmse:6.43474
# [43]	validation-rmse:6.43285
# [44]	validation-rmse:6.43187
# [45]	validation-rmse:6.43158
# [46]	validation-rmse:6.42987
# [47]	validation-rmse:6.42852
# [48]	validation-rmse:6.42810
# [49]	validation-rmse:6.42677
# [50]	validation-rmse:6.42588
# [51]	validation-rmse:6.42536
# [52]	validation-rmse:6.42413
# [53]	validation-rmse:6.42339
# [54]	validation-rmse:6.42232
# [55]	validation-rmse:6.42152
# [56]	validation-rmse:6.42073
# [57]	validation-rmse:6.42034
# [58]	validation-rmse:6.41949
# [59]	validation-rmse:6.41863
# ...
# [82]	validation-rmse:6.36692
# [83]	validation-rmse:6.36675
# [84]	validation-rmse:6.36626
# [85]	validation-rmse:6.36601
# [86]	validation-rmse:6.36579
# [87]	validation-rmse:6.36493
# [88]	validation-rmse:6.36468
# [89]	validation-rmse:6.36405
# [90]	validation-rmse:6.36379
# [91]	validation-rmse:6.36351
# [92]	validation-rmse:6.36303
# [93]	validation-rmse:6.36253
# [94]	validation-rmse:6.36187
# [95]	validation-rmse:6.36157
# [96]	validation-rmse:6.36124
# [97]	validation-rmse:6.36061
# [98]	validation-rmse:6.35971
# [99]	validation-rmse:6.35915
# [15:32:53] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.88418
# [1]	validation-rmse:13.73986
# [2]	validation-rmse:11.48340
# [3]	validation-rmse:9.89586
# [4]	validation-rmse:8.80083
# [5]	validation-rmse:8.05580
# [6]	validation-rmse:7.55718
# [7]	validation-rmse:7.22265
# [8]	validation-rmse:6.99612
# [9]	validation-rmse:6.84510
# [10]	validation-rmse:6.73948
# [11]	validation-rmse:6.66752
# [12]	validation-rmse:6.61332
# [13]	validation-rmse:6.57411
# [14]	validation-rmse:6.54175
# [15]	validation-rmse:6.51726
# [16]	validation-rmse:6.50022
# [17]	validation-rmse:6.48689
# [18]	validation-rmse:6.47750
# [19]	validation-rmse:6.47089
# [20]	validation-rmse:6.46392
# [21]	validation-rmse:6.45900
# [22]	validation-rmse:6.45476
# [23]	validation-rmse:6.45188
# [24]	validation-rmse:6.44887
# [25]	validation-rmse:6.44455
# [26]	validation-rmse:6.44218
# [27]	validation-rmse:6.43957
# [28]	validation-rmse:6.43689
# [29]	validation-rmse:6.43424
# [30]	validation-rmse:6.43195
# [31]	validation-rmse:6.43003
# [32]	validation-rmse:6.42767
# [33]	validation-rmse:6.42510
# [34]	validation-rmse:6.42331
# [35]	validation-rmse:6.42202
# [36]	validation-rmse:6.42139
# [37]	validation-rmse:6.42046
# [38]	validation-rmse:6.41875
# [39]	validation-rmse:6.41756
# [40]	validation-rmse:6.41625
# [41]	validation-rmse:6.41500
# [42]	validation-rmse:6.41356
# [43]	validation-rmse:6.41239
# [44]	validation-rmse:6.41017
# [45]	validation-rmse:6.40901
# [46]	validation-rmse:6.40735
#  44%|███████████████████████████▎                                  | 22/50 [05:35<07:07, 15.26s/trial, best loss: 6.356944843772784]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [24], in <cell line: 13>()
#       2 search_space = {
#       3     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       4     'learning_rate': hp.loguniform('learning_rate', -3, 0), #[exp(-3), exp(0)] = [0.05, 1]
#    (...)
#       9     'seed': 42
#      10 }
#      12 # fmin method tries to minimize the metric
# ---> 13 best_result = fmin(
#      14     fn=objective,
#      15     space=search_space,
#      16     algo=tpe.suggest,
#      17     max_evals=50,
#      18     trials=Trials()
#      19 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Input In [23], in objective(params)
#       4 # log paramters in mlflow
#       5 mlflow.log_params(params)
# ----> 6 booster = xgb.train(
#       7     # paramters are passed to xgboost
#       8     params=params,
#       9     # training on train data
#      10     dtrain=train,
#      11     # set boosting rounds
#      12     num_boost_round=100,
#      13     # validation is done on validation dataset
#      14     evals=[(valid, 'validation')],
#      15     # if model does not improve for 50 methods->stop
#      16     early_stopping_rounds=50
#      17 )
#      18 # make predictions
#      19 y_pred = booster.predict(valid)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:532, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     530 for k, arg in zip(sig.parameters, args):
#     531     kwargs[k] = arg
# --> 532 return f(**kwargs)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:1733, in Booster.update(self, dtrain, iteration, fobj)
#    1730 self._validate_features(dtrain)
#    1732 if fobj is None:
# -> 1733     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1734                                             ctypes.c_int(iteration),
#    1735                                             dtrain.handle))
#    1736 else:
#    1737     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %% [markdown]
# # Train the Model with a set of selected Parameters

# %%
params =  {'learning_rate': 0.20905792515510074,
            'max_depth': 7,
            'min_child_weight': 0.5241500975917085,
            'objective': 'reg:squarederror',
            'reg_alpha': 0.13309121698466933,
            'reg_lambda': 0.11277257081373988,
            'seed': 42}

# %%
# enable autologging
mlflow.xgboost.autolog()

booster = xgb.train(
            # paramters are passed to xgboost
            params=params,
            # training on train data
            dtrain=train,
            # set boosting rounds
            num_boost_round=1000,
            # validation is done on validation dataset
            evals=[(valid, 'validation')],
            # if model does not improve for 50 methods->stop
            early_stopping_rounds=50
        )

# %% [markdown]
# # Model Management
#
# same as above, but save the model as an artifact. Lower the number of boosting rounds to save time.

# %%
with mlflow.start_run(run_name="test_run") as run:
    
    mlflow.set_tag("developer", "frauke")
    
    mlflow.log_param("train-data-path", "../data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "../data/green_tripdata_2021-02.parquet")
    
    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)

    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    # save the model as an artifact
    mlflow.log_artifact(local_path="models/lin_reg.bin")#, artifact_path="models_pickle/")

# %% [markdown]
# A better way to save the model.

# %%
# disable autolog
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    best_params =  {'learning_rate': 0.20905792515510074,
                    'max_depth': 7,
                    'min_child_weight': 0.5241500975917085,
                    'objective': 'reg:squarederror',
                    'reg_alpha': 0.13309121698466933,
                    'reg_lambda': 0.11277257081373988,
                    'seed': 42}
    mlflow.log_params(best_params)
        
    booster = xgb.train(
                # paramters are passed to xgboost
                params=params,
                # training on train data
                dtrain=train,
                # set boosting rounds
                num_boost_round=100,
                # validation is done on validation dataset
                evals=[(valid, 'validation')],
                # if model does not improve for 50 methods->stop
                early_stopping_rounds=50
            )
        
    # make predictions
    y_pred = booster.predict(valid)
    # calculate error
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    # log metric
    mlflow.log_metric("rmse", rmse)
     
    # save preprocessor
    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    # log preprocessor
    mlflow.log_artifacts("models/preprocessor.b", artifact_path="preprocessor")
    # log the model
    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")

# %% [markdown]
# # Make Predictions using a saved Model from MLflow

# %%
logged_model = 'runs:/dbe24b153d444422bc22eb0baed7a9de/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: dbe24b153d444422bc22eb0baed7a9de

# %% [markdown]
# load as xgboost model

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)

# %%
xgboost_model

# %%
y_pred = xgboost_model.predict(valid)

# %%
y_pred
# Out:
# array([17.384949 ,  7.2070913, 21.283058 , ..., 13.594102 ,  7.2070913,
#         8.739125 ], dtype=float32)

# %% [markdown]
# # Train some more Models

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

# set autolog
mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):
    print(model_class)
    with mlflow.start_run():
        
        # data path
        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        # log preprocessor
        #mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        
        # log the rmse as metric
        mlflow.log_metric("rmse", rmse)
# Out:
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>
# <class 'sklearn.ensemble._forest.ExtraTreesRegressor'>
